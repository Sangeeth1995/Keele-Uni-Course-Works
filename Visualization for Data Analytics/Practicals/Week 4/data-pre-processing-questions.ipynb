# %% [markdown]
# # Course Name: Visualisation for Data Analytics
# # Objective: Data Pre-Processing

# %% [markdown]
# ### Dataset credit: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer
# #### NOTE: I have modified some parts of the dataset and added missng values in it

# %%
# Import Libraries
import numpy as np
import pandas as pd 

from pandas import Series, DataFrame

# %% [markdown]
# # Read Data given to in csv file with the lab

# %%
data = pd.read_csv('breast-cancer.csv')
#print(data.head())
data
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2       NaN
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2        na
# 4    no-recurrence-events  40-49   premeno        0-4       0-2
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34     5-Mar        no
# 285     recurrence-events  50-59      ge40      30-34     5-Mar        no
#
#      deg breast breast-quad irradiat
# 0    NaN   left    left_low       no
# ...

# %%
data.isnull().sum()
#Find the null value count of the attributes/colum header/features
# Out:
# class          0
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      2
# node-caps      3
# deg            3
# breast         0
# breast-quad    0
# irradiat       0
# dtype: int64

# %% [markdown]
# ### Q1. find null values for the column 'deg'

# %%
print(data['deg'].isnull())
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# Name: deg, Length: 286, dtype: bool

# %% [markdown]
# ### Q2 Find null values for the column 'node-cap'

# %%
print(data['node-caps'].isnull())
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# Name: node-caps, Length: 286, dtype: bool

# %%
# we have to define the null values as a list and pass it as an input while reading the data
missing_values = ["n/a", "na", "--", ' ', '?', 'NaN']
data = pd.read_csv('breast-cancer.csv', na_values = missing_values)
print(data['node-caps'].isnull())
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# Name: node-caps, Length: 286, dtype: bool

# %% [markdown]
# ### Q3. Count the percenatge of missing values in column 'deg'. Drop this columns if the percentage of missing values in greater than equal to 75%.

# %%
missing_val_count = data['deg'].isnull().sum()
print('Number of missing values = ', missing_val_count)
rows = data['deg'].count()
print('count =', rows)
percentage_missing  =  (missing_val_count *100)/rows
print('Percentage missing = ', percentage_missing)
if percentage_missing >=75.0:
    print('Delete this coulmn')
    data.drop('deg', axis= 1,inplace = True)
    
print(data)
# Out:
# Number of missing values =  3
# count = 283
# Percentage missing =  1.0600706713780919
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2       NaN
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2       NaN
# 4    no-recurrence-events  40-49   premeno        0-4       0-2       NaN
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34     5-Mar        no
# ...

# %% [markdown]
# ### Q4. Replace the 'null' values by average for the 'deg' column?

# %%
mean = data['deg'].mean()
print('mean value=', mean)
print('Befor:\n ', data['deg'])
data['deg'].fillna(mean, inplace=True)
print('after:\n',data['deg'])
# Out:
# mean value= 2.0424028268551235
# Befor:
#   0      NaN
# 1      2.0
# 2      2.0
# 3      NaN
# 4      2.0
#       ...
# 281    2.0
# 282    3.0
# 283    1.0
# 284    3.0
# 285    3.0
# Name: deg, Length: 286, dtype: float64
# after:
#  0      2.042403
# 1      2.000000
# 2      2.000000
# 3      2.042403
# 4      2.000000
#          ...
# 281    2.000000
# 282    3.000000
# 283    1.000000
# 284    3.000000
# 285    3.000000
# Name: deg, Length: 286, dtype: float64

# %% [markdown]
# ### Q5. Drop rows consisting of null or missing values

# %%
print('print data before and after dropping rows consisting of missing values')
data
# Out:
# print data before and after dropping rows consisting of missing values
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2       NaN
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2       NaN
# 4    no-recurrence-events  40-49   premeno        0-4       0-2       NaN
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34     5-Mar        no
# 285     recurrence-events  50-59      ge40      30-34     5-Mar        no
#
# ...

# %%
#Drop rows consisting of null values
data.dropna(inplace=True)
data
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 5    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 6    no-recurrence-events  50-59   premeno      25-29       0-2        no
# 9    no-recurrence-events  40-49   premeno      20-24       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34     5-Mar        no
# 285     recurrence-events  50-59      ge40      30-34     5-Mar        no
#
#           deg breast breast-quad irradiat
# ...

# %%
#Check for finding null values in the df
data.isnull().sum()
# Out:
# class          0
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      0
# deg            0
# breast         0
# breast-quad    0
# irradiat       0
# dtype: int64

# %% [markdown]
# ### Q6. Find and drop rows consisting of duplicate data?

# %%
#Finding duplicated data
data.duplicated()
# Out:
# 1      False
# 2       True
# 5      False
# 6      False
# 9      False
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# Length: 270, dtype: bool

# %%
# To drop all duplicate rows, just call the drop_duplicates() method off of the DataFrame.
data.drop_duplicates(inplace =True)

# %%
data.duplicated()
# Out:
# 1      False
# 5      False
# 6      False
# 9      False
# 10     False
#        ...
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# Length: 257, dtype: bool

# %% [markdown]
# ### Q7 Encode  columns consisting of categorical data using 'OrdinalEncoder'

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder
import numpy as np

# ordinal encode input variables
ordinal = OrdinalEncoder()
print(data)
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 5    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 6    no-recurrence-events  50-59   premeno      25-29       0-2        no
# 9    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 10   no-recurrence-events  40-49   premeno        0-4       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34     5-Mar        no
# 285     recurrence-events  50-59      ge40      30-34     5-Mar        no
#
#           deg breast breast-quad irradiat
# ...

# %%
data = ordinal.fit_transform(data)
print('Encode Data')
print(data)
# Out:
# Encode Data
# [[0. 2. 2. ... 1. 4. 0.]
#  [0. 4. 0. ... 0. 1. 0.]
#  [0. 3. 2. ... 0. 1. 0.]
#  ...
#  [1. 4. 0. ... 1. 2. 0.]
#  [1. 2. 0. ... 0. 1. 0.]
#  [1. 3. 0. ... 0. 1. 0.]]

# %% [markdown]
# More info
#
# https://machinelearningmastery.com/one-hot-encoding-for-categorical-data/#:~:text=This%20OrdinalEncoder%20class%20is%20intended,LabelEncoder%20class%20can%20be%20used.
